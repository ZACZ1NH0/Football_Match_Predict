# %%
# %pip install gspread oauth2client

# %%
import pandas as pd

def upload_to_sheets(df):
    df = df.toPandas()
    for col in df.select_dtypes(include=['datetime64', 'datetime']).columns:
        df[col] = df[col].dt.strftime('%Y-%m-%d')
    df = df.fillna("")
    
    scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
    creds = ServiceAccountCredentials.from_json_keyfile_name("/Workspace/Users/nguyenlongvu768@gmail.com/DATN/turing-seeker-485616-e7-fdd19d0d44fc.json", scope)
    client = gspread.authorize(creds)

    # 2. Mở file Sheet bằng ID
    sheet = client.open_by_key("1qrbQTBuN3eSz1yDxpVQQ0r0aaGx_QhftJS5vMeIlnoA").sheet1

    # 3. Xóa dữ liệu cũ và ghi đè dữ liệu mới từ Pandas DataFrame
    sheet.clear()
    sheet.update([df.columns.values.tolist()] + df.values.tolist())
    print("✅ Đã cập nhật Google Sheet thành công!")

upload_to_sheets(spark_df_1)
